# %%
from pathlib import Path
import pandas as pd

from file_converter.core.pipeline import load_file

# %%
INPUT_PATH = Path("../data/input/waleron@gmail.com_0_summarizedActivities.json")
OUTPUT_PATH = Path("../data/output/events.parquet")

OUTPUT_PATH.parent.mkdir(parents=True, exist_ok=True)

INPUT_PATH, OUTPUT_PATH
# Out:
# (WindowsPath('../data/input/waleron@gmail.com_0_summarizedActivities.json'),
#  WindowsPath('../data/output/events.parquet'))

# %%
df = load_file(INPUT_PATH)

df.shape
# Out:
# (1, 1)

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

df.head(5)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0  [{'activityId': 21318112394, 'uuidMsb': 8599143760790179147, 'uuidLsb': -9083411949183520159, 'name': 'Gdynia Walking', 'activityType': 'walking', 'userProfileId': 112174554, 'timeZoneId': 124, 'beginTimestamp': 1766332660000, 'eventTypeId': 9, 'rule': 'subscribers', 'sportType': 'STEPS', 'startTimeGmt': 1766332660000.0, 'startTimeLocal': 1766336260000.0, 'duration': 3486513.916015625, 'distance': 12269.999694824219, 'elevationGain': 1400.0, 'elevationLoss': 0.0, 'avgSpeed': 0.0035000000149011615, 'maxSpeed': 0.23510000705718995, 'avgHr': 81.0, 'maxHr': 135.0, 'minHr': 49.0, 'avgRunCadence': 0.0, 'maxRunCadence': 76.0, 'steps': 134.0, 'calories': 779.34372, 'bmrCalories': 368.72175999999996, 'startLongitude': 18.55265191756189, 'startLatitude': 54.47925405576825, 'avgStrideLength': 250.25952359572742, 'avgFractionalCadence': 0.421875, 'maxFractionalCadence': 0.5, 'elapsedDuration': 3486513.916015625, 'movingDuration': 34000.0, 'deviceId': 3387113934, 'minTemperature': 21.0, 'maxTemperature': 28.0, 'minElevation': -15019.999694824219, 'maxElevation': -13319.999694824219, 'avgDoubleCadence': 0.84375, 'maxDoubleCadence': 153.0, 'locationName': 'Gdynia', 'summarizedDiveInfo': {}, 'maxVerticalSpeed': 0.04000091552734375, 'manufacturer': 'GARMIN', 'lapCount': 1, 'endLongitude': 18.553523467853665, 'endLatitude': 54.47913729585707, 'maxLatitude': 54.47932546958327, 'maxLongitude': 18.554149931296706, 'minLatitude': 54.47875885292888, 'minLongitude': 18.55205344967544, 'hrTimeInZone_0': 2990487, 'hrTimeInZone_1': 433029, 'hrTimeInZone_2': 56997, 'hrTimeInZone_3': 6001, 'hrTimeInZone_4': 0, 'hrTimeInZone_5': 0, 'hrTimeInZone_6': 0, 'parent': False, 'purposeful': False, 'autoCalcCalories': False, 'favorite': False, 'pr': False, 'decoDive': False, 'elevationCorrected': False, 'atpActivity': False}, {'activityId': 21318111540, 'uuidMsb': -8511676106001592708, 'uuidLsb': -6329987480283003086, 'name': 'Yoga', 'activityType': 'yoga', 'userProfileId': 112174554, 'timeZoneId': 124, 'beginTimestamp': 1766323325000, 'eventTypeId': 9, 'rule': 'subscribers', 'sportType': 'TRAINING', 'startTimeGmt': 1766323325000.0, 'startTimeLocal': 1766326925000.0, 'duration': 2213743.896484375, 'avgHr': 97.0, 'maxHr': 147.0, 'minHr': 41.0, 'calories': 691.3533, 'bmrCalories': 234.64111999999997, 'avgFractionalCadence': 0.0, 'maxFractionalCadence': 0.0, 'elapsedDuration': 2213743.896484375, 'movingDuration': 0.0, 'deviceId': 3387113934, 'minTemperature': 26.0, 'maxTemperature': 35.0, 'summarizedDiveInfo': {}, 'manufacturer': 'GARMIN', 'lapCount': 1, 'startStress': 93.0, 'endStress': 79.0, 'differenceStress': -14.0, 'avgStress': 73.0, 'maxStress': 99.0, 'hrTimeInZone_0': 873006, 'hrTimeInZone_1': 1262737, 'hrTimeInZone_2': 47999, 'hrTimeInZone_3': 30002, 'hrTimeInZone_4': 0, 'hrTimeInZone_5': 0, 'hrTimeInZone_6': 0, 'parent': False, 'purposeful': False, 'autoCalcCalories': False, 'favorite': False, 'pr': False, 'decoDive': False, 'elevationCorrected': False, 'atpActivity': False}, {'activityId': 21307749972, 'uuidMsb': -7537172507776692851, 'uuidLsb': -4892721551988048705, 'name': 'Strength', 'activityType': 'strength_training', 'userProfileId': 112174554, 'timeZoneId': 124, 'beginTimestamp': 1766243228000, 'eventTypeId': 9, 'rule': 'subscribers', 'sportType': 'TRAINING', 'startTimeGmt': 1766243228000.0, 'startTimeLocal': 1766246828000.0, 'duration': 3653797.119140625, 'distance': 0.0, 'avgSpeed': 0.0, 'avgHr': 89.0, 'maxHr': 135.0, 'minHr': 62.0, 'steps': 8.0, 'calories': 976.2746599999999, 'bmrCalories': 389.67186, 'avgFractionalCadence': 0.0, 'maxFractionalCadence': 0.0, 'elapsedDuration': 3653797.119140625, 'movingDuration': 3653797.119140625, 'deviceId': 3387113934, 'minTemperature': 26.0, 'maxTemperature': 32.0, 'summarizedExerciseSets': [{'category': 'UNKNOWN', 'reps': 4, 'volume': 0, 'duration': 3653797.119140625, 'sets': 1, 'maxWeight': 0}], 'summarizedDiveInfo': {}, 'manufacturer': 'GARMIN', 'lapCount': 1, 'activeSets': 1, 'totalSets': 1, 'totalReps': ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 1 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   summarizedActivitiesExport  1 non-null      object
# dtypes: object(1)
# memory usage: 140.0+ bytes

# %%
df.columns
# Out:
# Index(['summarizedActivitiesExport'], dtype='object')
