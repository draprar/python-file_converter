# %%
from pathlib import Path
import pandas as pd

from file_converter.core.pipeline import load_file

# %%
INPUT_PATH = Path("../data/input/Activities.csv")
OUTPUT_PATH = Path("../data/output/activities.parquet")

OUTPUT_PATH.parent.mkdir(parents=True, exist_ok=True)

INPUT_PATH, OUTPUT_PATH
# Out:
# (WindowsPath('../data/input/Activities.csv'),
#  WindowsPath('../data/output/activities.parquet'))

# %%
df = load_file(INPUT_PATH)

df.shape
# Out:
# (1340, 34)

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

df.head(5)
# Out:
#        Activity Type                 Date  Favorite     Title Distance  \
# 0               Yoga  2026-01-10 19:00:53     False      Yoga       --
# 1             Cardio  2026-01-09 16:55:58     False    Boxing     0.00
# 2             Cardio  2026-01-08 19:56:04     False    Boxing     0.00
# 3  Strength Training  2026-01-07 20:29:21     False  Strength     0.00
# 4               Yoga  2026-01-07 12:26:14     False      Yoga       --
#
#   Calories      Time Avg HR Max HR Avg Bike Cadence Max Bike Cadence  \
# 0      173  00:43:17     92    136               --               --
# 1      658  01:03:33    145    179               --               --
# 2      798  01:11:37    148    196               --               --
# 3      236  01:01:05     89    113               --               --
# 4       83  00:15:58    102    119               --               --
#
#   Avg Speed Max Speed Total Ascent Total Descent Avg Stride Length  \
# 0        --        --           --            --                --
# 1        --        --           --            --                --
# 2        --        --           --            --                --
# 3        --        --           --            --                --
# 4        --        --           --            --                --
#
#    Training Stress Score® Steps Total Reps Total Poses Min Temp Decompression  \
# 0                     0.0    --         --          --     28.0            No
# 1                     0.0    --         --          --     19.0            No
# 2                     0.0    --         --          --     19.0            No
# 3                     0.0    10          5           1     21.0            No
# 4                     0.0    --         --          --     28.0            No
#
#   Best Lap Time  Number of Laps Max Temp Stress Change Stress Start  \
# 0      00:43:17               1     31.0           -18           96
# 1      01:03:33               1     26.0            --           --
# 2      01:11:37               1     25.0            --           --
# 3      01:01:05               1     29.0            --           --
# 4      00:15:58               1     29.0            90            0
#
#   Stress End Avg Stress Max Stress Moving Time Elapsed Time Min Elevation  \
# 0         78         74         98    00:00:00     00:43:17            --
# 1         --         --         --    00:00:00     01:03:33          -215
# 2         --         --         --    00:00:00     01:11:37          -150
# 3         --         --         --    01:01:05     01:01:05            --
# 4         90         88         97    00:00:00     00:15:58            --
#
#   Max Elevation
# 0            --
# 1           254
# 2          -141
# 3            --
# 4            --

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Activity Type           1340 non-null   object
#  1   Date                    1340 non-null   object
#  2   Favorite                1340 non-null   bool
#  3   Title                   1340 non-null   object
#  4   Distance                1340 non-null   object
#  5   Calories                1340 non-null   object
#  6   Time                    1340 non-null   object
#  7   Avg HR                  1340 non-null   object
#  8   Max HR                  1340 non-null   object
#  9   Avg Bike Cadence        1340 non-null   object
#  10  Max Bike Cadence        1340 non-null   object
#  11  Avg Speed               1340 non-null   object
#  12  Max Speed               1340 non-null   object
#  13  Total Ascent            1340 non-null   object
#  14  Total Descent           1340 non-null   object
#  15  Avg Stride Length       1340 non-null   object
#  16  Training Stress Score®  1340 non-null   float64
#  17  Steps                   1340 non-null   object
#  18  Total Reps              1340 non-null   object
#  19  Total Poses             1340 non-null   object
#  20  Min Temp                1340 non-null   object
#  21  Decompression           1340 non-null   object
#  22  Best Lap Time           1340 non-null   object
#  23  Number of Laps          1340 non-null   int64
#  24  Max Temp                1340 non-null   object
#  25  Stress Change           1340 non-null   object
#  26  Stress Start            1340 non-null   object
#  27  Stress End              1340 non-null   object
#  28  Avg Stress              1340 non-null   object
#  29  Max Stress              1340 non-null   object
#  30  Moving Time             1340 non-null   object
#  31  Elapsed Time            1340 non-null   object
#  32  Min Elevation           1340 non-null   object
#  33  Max Elevation           1340 non-null   object
# dtypes: bool(1), float64(1), int64(1), object(31)
# memory usage: 346.9+ KB

# %%
df.columns
# Out:
# Index(['Activity Type', 'Date', 'Favorite', 'Title', 'Distance', 'Calories',
#        'Time', 'Avg HR', 'Max HR', 'Avg Bike Cadence', 'Max Bike Cadence',
#        'Avg Speed', 'Max Speed', 'Total Ascent', 'Total Descent',
#        'Avg Stride Length', 'Training Stress Score®', 'Steps', 'Total Reps',
#        'Total Poses', 'Min Temp', 'Decompression', 'Best Lap Time',
#        'Number of Laps', 'Max Temp', 'Stress Change', 'Stress Start',
#        'Stress End', 'Avg Stress', 'Max Stress', 'Moving Time', 'Elapsed Time',
#        'Min Elevation', 'Max Elevation'],
#       dtype='object')
